# %%
import gdown

# %%
url ="https://drive.google.com/file/d/1WNottNNKLf4R9YeyE2EttD5jyR4gc38-/view?usp=sharing"

# %%
url.split("/")[-2]
# Out:
# '1WNottNNKLf4R9YeyE2EttD5jyR4gc38-'

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1WNottNNKLf4R9YeyE2EttD5jyR4gc38-'

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix + file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1WNottNNKLf4R9YeyE2EttD5jyR4gc38-
# From (redirected): https://drive.google.com/uc?export=download&id=1WNottNNKLf4R9YeyE2EttD5jyR4gc38-&confirm=t&uuid=de759459-fe8b-4cdf-b938-c35b75e961c2
# To: c:\Users\Public\Rahul_Projects\Chest_Disease_Classification\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:02<00:00, 16.5MB/s]
# 'Chest-CT-Scan-data.zip'
